# %% [markdown]
# <a href="https://colab.research.google.com/github/SHIVAM1KUMAR/PythonAndDataScience/blob/main/W1S1%2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World ", end='with ')
print('Shivam kkk')
# Out:
# Hello World with Shivam kkk

# %%
print("Data" ,"Science", "Mentorship" ,"Program" ,"By" ,"CampusX" , sep='-')
# Out:
# Data-Science-Mentorship-Program-By-CampusX
