# %% [markdown]
# <a href="https://colab.research.google.com/github/SHIVAM1KUMAR/PythonAndDataScience/blob/main/W1Task's.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World ", end='with ')
print('Shivam kkk')
# Out:
# Hello World with Shivam kkk

# %%
print("Data" ,"Science", "Mentorship" ,"Program" ,"By" ,"CampusX" , sep='-')
# Out:
# Data-Science-Mentorship-Program-By-CampusX

# %%
s1 = {1,2,3,4,5}
s2 = {4,5,6,7,8}

# s1 | s2
s1.intersection(s1)
# Out:
# {1, 2, 3, 4, 5}

# %%
d5 = {'name':'nitish','name':'rahul'}
d5
# Out:
# {'name': 'rahul'}

# %%
my_dict = {'name': 'Jack', 'age': 26}
# []
my_dict['age']
# Out:
# 26

# %%
def is_even(num):
  """
  This function returns if a given number is odd or even
  input - any valid integer
  output - odd/even
  created on - 16th Nov 2022
  """
  if type(num) == int:
    if num % 2 == 0:
      return 'even'
    else:
      return 'odd'
  else:
    return 'pagal hai kya?'

# %%
def g(y):
    print(x)
    print(x+1)
x = 5
g(x)
print(x)
# Out:
# 5
# 6
# 5

# %%
is_even(5)
# Out:
# 'odd'

# %%
def g(x):
    def h():
        x = 'abc'
    x = x + 1
    print('in g(x): x =', x)
    h()
    return x

x = 3
z = g(x)
# Out:
# in g(x): x = 4

# %%
# HOF
def transform(f,L):
  output = []
  for i in L:
    output.append(f(i))

  print(output)

L = [1,2,3,4,5]

transform(lambda x:x**3,L)
# Out:
# [1, 8, 27, 64, 125]
